# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("spotify-2023.csv", encoding = "unicode_escape")

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df.shape
# Out:
# (953, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df.isnull().mean()*100
# Out:
# track_name              0.00000
# artist(s)_name          0.00000
# artist_count            0.00000
# released_year           0.00000
# released_month          0.00000
# released_day            0.00000
# in_spotify_playlists    0.00000
# in_spotify_charts       0.00000
# streams                 0.00000
# in_apple_playlists      0.00000
# in_apple_charts         0.00000
# in_deezer_playlists     0.00000
# in_deezer_charts        0.00000
# in_shazam_charts        5.24659
# bpm                     0.00000
# key                     9.96852
# mode                    0.00000
# danceability_%          0.00000
# valence_%               0.00000
# energy_%                0.00000
# acousticness_%          0.00000
# instrumentalness_%      0.00000
# liveness_%              0.00000
# speechiness_%           0.00000
# dtype: float64

# %%
df.dropna(subset = ['in_shazam_charts', 'key' ], inplace = True)

# %%
df.isnull().mean()*100
# Out:
# track_name              0.0
# artist(s)_name          0.0
# artist_count            0.0
# released_year           0.0
# released_month          0.0
# released_day            0.0
# in_spotify_playlists    0.0
# in_spotify_charts       0.0
# streams                 0.0
# in_apple_playlists      0.0
# in_apple_charts         0.0
# in_deezer_playlists     0.0
# in_deezer_charts        0.0
# in_shazam_charts        0.0
# bpm                     0.0
# key                     0.0
# mode                    0.0
# danceability_%          0.0
# valence_%               0.0
# energy_%                0.0
# acousticness_%          0.0
# instrumentalness_%      0.0
# liveness_%              0.0
# speechiness_%           0.0
# dtype: float64

# %%
df.nunique()
# Out:
# track_name              811
# artist(s)_name          571
# artist_count              8
# released_year            46
# released_month           12
# released_day             31
# in_spotify_playlists    756
# in_spotify_charts        76
# streams                 814
# in_apple_playlists      206
# in_apple_charts         163
# in_deezer_playlists     292
# in_deezer_charts         31
# in_shazam_charts        187
# bpm                     122
# key                      11
# mode                      2
# danceability_%           71
# valence_%                94
# energy_%                 78
# acousticness_%           93
# instrumentalness_%       36
# liveness_%               66
# speechiness_%            48
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            817 non-null    object
#  1   artist(s)_name        817 non-null    object
#  2   artist_count          817 non-null    int64
#  3   released_year         817 non-null    int64
#  4   released_month        817 non-null    int64
#  5   released_day          817 non-null    int64
#  6   in_spotify_playlists  817 non-null    int64
#  7   in_spotify_charts     817 non-null    int64
#  8   streams               817 non-null    object
#  9   in_apple_playlists    817 non-null    int64
#  10  in_apple_charts       817 non-null    int64
#  11  in_deezer_playlists   817 non-null    object
#  12  in_deezer_charts      817 non-null    int64
#  13  in_shazam_charts      817 non-null    object
#  14  bpm                   817 non-null    int64
# ...

# %%
per_year_count = df.groupby('released_year')['track_name'].count().reset_index()
per_year_count.columns = ['Year', 'Number of Songs Released']
year_count = per_year_count.sort_values('Year')

plt.figure(figsize=(6, 6))
plt.bar(year_count['Year'], year_count['Number of Songs Released'], width = 0.9)
plt.xlabel('Year')
plt.ylabel('Number of Songs Released')
plt.title('Number of Songs Released Year-Wise')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability if needed

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['artist_count'], bins=20, edgecolor='k')  # Adjust the number of bins as needed
plt.xlabel('Artist Count')  # Corrected from 'xlable' to 'xlabel'
plt.ylabel('Frequency')  # Corrected from 'ylable' to 'ylabel'
plt.title('Distribution of Artist Counts')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Sort the DataFrame by 'streams' in descending order and select the top 10 rows
Top_10_Streams = df.sort_values(by='streams', ascending=False).head(10)

# %%
plt.figure(figsize=(10, 6))
plt.barh(Top_10_Streams['track_name'], Top_10_Streams['streams'], color='skyblue')
plt.xlabel('Streams')
plt.ylabel('Track Name')
plt.title('Top 10 Streamed Songs on Spotify')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# Convert the 'in_spotify_charts' column to a numeric data type
df['in_spotify_charts'] = pd.to_numeric(df['in_spotify_charts'], errors='coerce')

# Sort the DataFrame by 'in_spotify_charts' in descending order and select the top 10 rows
Top_10_Streams_in_spotify_charts = df.sort_values(by='in_spotify_charts', ascending=False).head(10)

# Create the horizontal bar plot
plt.figure(figsize=(14, 6))
plt.barh(Top_10_Streams_in_spotify_charts['track_name'], Top_10_Streams_in_spotify_charts['in_spotify_charts'], color='Yellow')
plt.xlabel('in_spotify_charts')
plt.ylabel('track_name')
plt.title('Top 10 Streamed Songs on Spotify charts')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# Convert the 'in_spotify_playlists' column to a numeric data type
df['in_spotify_playlists'] = pd.to_numeric(df['in_spotify_playlists'], errors='coerce')

# Sort the DataFrame by 'in_spotify_playlists' in descending order and select the top 10 rows
Top_10_Streams_in_spotify_playlist = df.sort_values(by='in_spotify_playlists', ascending=False).head(10)

# Create the horizontal bar plot
plt.figure(figsize=(14, 6))
plt.barh(Top_10_Streams_in_spotify_playlist['track_name'], Top_10_Streams_in_spotify_playlist['in_spotify_playlists'], color='Orange')
plt.xlabel('in_spotify_playlists')
plt.ylabel('track_name')
plt.title('Top 10 Streamed Songs on Spotify playlist')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# Convert the 'in_apple_playlists' column to a numeric data type
df['in_apple_playlists'] = pd.to_numeric(df['in_apple_playlists'], errors='coerce')

# Sort the DataFrame by 'in_apple_playlists' in descending order and select the top 10 rows
Top_10_Streams_in_apple_playlists = df.sort_values(by='in_apple_playlists', ascending=False).head(10)

# Create a vertical bar plot for 'in_apple_playlists'
plt.figure(figsize=(10, 8))
plt.bar(Top_10_Streams_in_apple_playlists['track_name'], Top_10_Streams_in_apple_playlists['in_apple_playlists'], color='Brown')
plt.xlabel('Track Name')
plt.ylabel('in_apple_playlists')
plt.title('Top 10 Streamed Songs on Apple playlists')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# The code provided here generates a vertical bar plot for the top 10 streamed songs on Apple playlists based on their 'in_apple_playlists' count. Here's a summary:
#
# Data Preparation:
#
# The 'in_apple_playlists' column is converted to a numeric data type, with any conversion errors set to NaN (Not a Number).
# Top 10 Songs Selection:
#
# The DataFrame is sorted by 'in_apple_playlists' in descending order to identify the top 10 songs with the highest 'in_apple_playlists' count.
# Bar Plot Creation:
#
# A vertical bar plot is created using Matplotlib.
# The x-axis represents the 'Track Name,' and the y-axis represents the 'in_apple_playlists' count.
# The bars are colored in brown.
# The x-axis labels (track names) are rotated 90 degrees for better readability.
# Plot Display:
#
# The plot is displayed using plt.show().
# This bar plot allows you to visualize and compare the top 10 songs that have been streamed the most on Apple playlists, as indicated by their 'in_apple_playlists' count. It provides insights into the popularity of these songs on the Apple Music platform.

# %%
# Convert the 'in_apple_charts' column to a numeric data type
df['in_apple_charts'] = pd.to_numeric(df['in_apple_charts'], errors='coerce')

# Sort the DataFrame by 'in_apple_charts' in descending order and select the top 10 rows
Top_10_Streamed_songs_in_apple_charts = df.sort_values(by='in_apple_charts', ascending=False).head(10)

# Create a vertical bar plot for 'in_apple_charts'
plt.figure(figsize=(10, 6))
plt.bar(Top_10_Streamed_songs_in_apple_charts['track_name'], Top_10_Streamed_songs_in_apple_charts['in_apple_charts'], color='Blue')
plt.xlabel('Track Name')
plt.ylabel('in_apple_charts')
plt.title('Top 10 Songs on Apple Charts')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# The code provided here performs the following tasks and generates a vertical bar plot representing the top 10 songs on Apple Charts based on their 'in_apple_charts' count:
#
# Data Preparation:
#
# The 'in_apple_charts' column is converted to a numeric data type, with any conversion errors set to NaN (Not a Number).
# Top 10 Songs Selection:
#
# The DataFrame is sorted by 'in_apple_charts' in descending order to identify the top 10 songs with the highest 'in_apple_charts' count.
# Bar Plot Creation:
#
# A vertical bar plot is created using Matplotlib.
# The x-axis represents the 'Track Name,' and the y-axis represents the 'in_apple_charts' count.
# The bars are colored in blue.
# The x-axis labels (track names) are rotated 90 degrees for better readability.
# Plot Display:
#
# The plot is displayed using plt.show().
# This bar plot allows you to visualize and compare the top 10 songs that have performed the best on Apple Charts, as indicated by their 'in_apple_charts' count. It provides insights into the popularity of these songs on the Apple Charts platform

# %%
# Convert the 'in_spotify_playlists' and 'in_apple_playlists' columns to numeric data types
df['in_spotify_playlists'] = pd.to_numeric(df['in_spotify_playlists'], errors='coerce')
df['in_apple_playlists'] = pd.to_numeric(df['in_apple_playlists'], errors='coerce')

# Create a new column 'total_playlists' by summing the two columns
df['total_playlists'] = df['in_spotify_playlists'] + df['in_apple_playlists']

# Sort the DataFrame by 'total_playlists' in descending order and select the top 10 rows
top_10_tracks_total_playlists = df.sort_values(by='total_playlists', ascending=False).head(10)

# Create a vertical bar plot for the top 10 tracks based on 'total_playlists'
plt.figure(figsize=(12, 6))
plt.bar(top_10_tracks_total_playlists['track_name'], top_10_tracks_total_playlists['total_playlists'], color='purple')
plt.xlabel('Track Name')
plt.ylabel('Total Playlists Count')
plt.title('Top 10 Tracks by Total Playlists Count')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# The code provided here performs the following tasks and generates a bar plot representing the top 10 tracks based on their total playlists count:
#
# Data Preparation:
#
# The 'in_spotify_playlists' and 'in_apple_playlists' columns are converted to numeric data types, with any conversion errors set to NaN (Not a Number).
# A new column 'total_playlists' is created by summing the values in 'in_spotify_playlists' and 'in_apple_playlists' for each track.
# Top 10 Tracks Selection:
#
# The DataFrame is sorted by 'total_playlists' in descending order to identify the top 10 tracks with the highest total playlists count.
# Bar Plot Creation:
#
# A vertical bar plot is created using Matplotlib.
# The x-axis represents the 'Track Name,' and the y-axis represents the 'Total Playlists Count.'
# The bars are colored in purple.
# The x-axis labels (track names) are rotated 90 degrees for better readability.
# Plot Display:
#
# The plot is displayed using plt.show().
# This bar plot allows you to visualize and compare the top 10 tracks in your dataset based on their total playlists count. It helps identify which tracks are the most popular and have been featured in the most playlists across both Spotify and Apple Music, as represented by the 'total_playlists' column.

# %%
# Different Modes
Types_of_mode = df['mode'].value_counts().reset_index()
Types_of_mode.columns = ['Mode', 'Count']

# Create a pie chart for the modes
plt.figure(figsize=(6, 6))
plt.pie(Types_of_mode['Count'], labels=Types_of_mode['Mode'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Modes')
plt.axis('equal')
plt.show()

# %% [markdown]
# The pie chart created represents the distribution of different modes in your dataset. Here's a summary of what it indicates:
#
# Slices: Each slice of the pie chart represents a different mode (e.g., Major or Minor) present in your dataset.
#
# Labels: The labels outside the pie chart indicate the mode names (e.g., "Major" and "Minor").
#
# Percentages: Each slice is accompanied by a percentage value, indicating the proportion of songs in your dataset that belong to that mode. These percentages are displayed using the autopct parameter.
#
# Start Angle: The startangle parameter determines the angle at which the pie chart starts. In this case, it's set to 90 degrees, which means the chart begins with the "Major" mode slice.
#
# Interpreting the pie chart:
#
# The pie chart provides a visual representation of the distribution of different modes in your dataset.
#
# It shows the relative prevalence of each mode. For example, if one slice is larger than the others, it indicates that a higher percentage of songs in your dataset belong to that mode.
#
# The chart allows you to quickly see the overall composition of modes in your music dataset.
#
# In this specific chart, you can see the distribution of major and minor modes in your music data. The percentages attached to each slice indicate the proportion of songs in each mode category.

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['danceability_%'], bins=20, color='skyblue', edgecolor='k')
plt.title('Distribution of Danceability Percentages')
plt.xlabel('Danceability Percentage')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Based on the histogram of danceability percentages in your dataset, we can draw the following conclusions:
#
# Distribution Shape: The distribution of danceability percentages appears to be somewhat right-skewed, with a longer tail on the right side of the histogram. This suggests that there are more songs in the dataset with higher danceability percentages.
#
# Central Tendency: The central tendency of danceability percentages seems to be around the higher values, indicating that a significant portion of the songs in the dataset have relatively high danceability percentages.
#
# Spread: While the central tendency is higher, there is still a spread of danceability percentages across the dataset. Some songs have lower danceability percentages, contributing to the right-skewed shape of the distribution.
#
# Bins: The histogram is divided into 20 bins, providing a granular view of the distribution. This allows you to see how the songs are distributed across different ranges of danceability percentages.

# %%
# Create a histogram for the 'valence_%' column
plt.figure(figsize=(8, 6))
plt.hist(df['valence_%'], bins=10, color='Orange', edgecolor='k')
plt.title('Distribution of Valence Percentage')
plt.xlabel('Valence Percentage')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The histogram you've created represents the distribution of valence percentages in your dataset. Here's a summary of what it indicates:
#
# X-axis (Valence Percentage): This axis represents the range of valence percentages in your dataset. It's divided into intervals or bins (in this case, 10 bins) that cover the entire range of valence percentages.
#
# Y-axis (Frequency): This axis represents the frequency or count of data points falling into each bin. It shows how many songs have valence percentages within each bin's range.
#
# Bars: Each bar in the histogram corresponds to a bin on the x-axis. The height of the bar represents the number of songs in your dataset that have valence percentages within the range of that bin. Taller bars indicate more songs with valence percentages in that specific range.
#
# Bins: Bins are intervals or ranges of valence percentages. In your histogram, you've divided the entire range of valence percentages into 10 equally spaced bins. The data points are counted and grouped into these bins.

# %%
import matplotlib.pyplot as plt

# Create a histogram for the 'energy_%' column
plt.figure(figsize=(8, 6))
plt.hist(df['energy_%'], bins=10, color='green', edgecolor='k')
plt.title('Distribution of Energy Percentage')
plt.xlabel('Energy Percentage')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The histogram you've created represents the distribution of energy percentages in your dataset. Here's a summary of what it indicates:
#
# X-axis (Energy Percentage): This axis represents the range of energy percentages in your dataset. It's divided into intervals or bins (in this case, 10 bins) that cover the entire range of energy percentages.
#
# Y-axis (Frequency): This axis represents the frequency or count of songs falling into each bin. It shows how many songs have energy percentages within each bin's range.
#
# Bars: Each bar in the histogram corresponds to a bin on the x-axis. The height of the bar represents the number of songs in your dataset that have energy percentages within the range of that bin. Taller bars indicate more songs with energy percentages in that specific range.
#
# Bins: Bins are intervals or ranges of energy percentages. In your histogram, you've divided the entire range of energy percentages into 10 equally spaced bins. The data points are counted and grouped into these bins.
#
# Interpreting the histogram:
#
# The histogram appears to be relatively symmetric, suggesting that there is a fairly even distribution of energy percentages across your dataset.
#
# There is a peak in the center of the distribution, indicating that a substantial number of songs have energy percentages around a certain central value.
#
# The spread of the data is moderate, indicating a range of energy percentages from lower to higher values.
#
# Overall, the histogram provides insights into the distribution of energy percentages in your dataset, which can help you understand the energy characteristics of the music. It suggests that there is diversity in energy levels, with songs exhibiting a range of energy from low to high.

# %%
plt.figure(figsize=(8,6))
plt.hist(df['acousticness_%'], bins = 10 , color= 'skyblue', edgecolor= 'k')
plt.title('Amount of acoustic sound in the song')
plt.xlabel('acousticness_%')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(df['instrumentalness_%'], color='black', fill=True)
plt.title('Kernel Density Estimate of Instrumentalness Percentage')
plt.xlabel('Instrumentalness Percentage')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# This code generates a KDE plot to visualize the distribution of 'instrumentalness_%' in the dataset. The plot shows how the values of 'instrumentalness_%' are distributed, providing insights into the data's density and shape. It's a useful way to understand the distribution of this variable in your dataset.

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(df['liveness_%'], color='blue', fill=True)
plt.title('Kernel Density Estimate of Liveness Percentage')
plt.xlabel('Liveness Percentage')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# The code helps you visualize how the values of 'liveness_%' are distributed in your dataset. The KDE plot provides insights into the density and shape of the distribution of this variable.

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(df['speechiness_%'], color='orange', fill=True)
plt.title('Kernel Density Estimate of speechiness Percentage')
plt.xlabel('speechiness Percentage')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# The code you provided generates a Kernel Density Estimate (KDE) plot to visualize the distribution of the 'speechiness_%' variable in your dataset. Here's a summary of the code:
#
# plt.figure(figsize=(8, 6)): This line creates a new figure (plot) with a specified size of 8 inches in width and 6 inches in height, setting the dimensions for the upcoming plot.
#
# sns.kdeplot(df['speechiness_%'], color='orange', fill=True): This line uses the Seaborn library (sns) to create a KDE plot. It plots the distribution of the 'speechiness_%' column from the DataFrame df. The KDE plot uses an orange line to represent the estimated density, and the fill=True argument fills the area under the curve.
#
# plt.title('Kernel Density Estimate of Speechiness Percentage'): This sets the title of the plot to "Kernel Density Estimate of Speechiness Percentage."
#
# plt.xlabel('Speechiness Percentage'): This labels the x-axis with "Speechiness Percentage," indicating that the horizontal axis represents the values of the 'speechiness_%' variable.
#
# plt.ylabel('Density'): This labels the y-axis with "Density," indicating that the vertical axis represents the density or probability of observing different values of 'speechiness_%.'
#
# plt.show(): This command displays the generated KDE plot on the screen.
#
# In summary, the code helps you visualize how the values of 'speechiness_%' are distributed in your dataset. The KDE plot provides insights into the density and shape of the distribution of this variable.
